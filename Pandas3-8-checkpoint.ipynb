# %%
#pandas3-4

import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)

data = {'coll': ['1', '2', '3', 'teks'], 
        'col2': ['1', '2', '3', '4']}

df= pd.DataFrame(data)

df
# Out:
# 2.0.3
# 1.24.3
#    coll col2
# 0     1    1
# 1     2    2
# 2     3    3
# 3  teks    4

# %%
df.dtypes
# Out:
# coll    object
# col2    object
# dtype: object

# %%
df_x= df.astype({'col2': 'float'}) 
df_x
#fungsi astype()
# Out:
#    coll  col2
# 0     1   1.0
# 1     2   2.0
# 2     3   3.0
# 3  teks   4.0

# %%
df_x.dtypes
# Out:
# coll     object
# col2    float64
# dtype: object

# %%
df.apply(pd.to_numeric, errors='coerce')
#numeric()
# Out:
#    coll  col2
# 0   1.0     1
# 1   2.0     2
# 2   3.0     3
# 3   NaN     4

# %%
n_rows = 5
n_cols = 2 
cols = ['bil_pecahan', 'bil_bulat']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)

# Mengonversi kolom 'bil_pecahan' ke tipe float
df['bil_pecahan'] = df['bil_pecahan'].astype('float')

df.index = pd.date_range(start='2023-01-01', periods=n_rows, freq='H')

# Reset index agar 'date' menjadi kolom
df = df.reset_index()

# Menambahkan kolom teks
df['teks'] = list('ABCDE')

df
# Out:
#                 index  bil_pecahan  bil_bulat teks
# 0 2023-01-01 00:00:00          8.0         12    A
# 1 2023-01-01 01:00:00         11.0          9    B
# 2 2023-01-01 02:00:00         15.0          4    C
# 3 2023-01-01 03:00:00         19.0          4    D
# 4 2023-01-01 04:00:00         17.0         15    E

# %%
df.dtypes
# Out:
# index          datetime64[ns]
# bil_pecahan           float64
# bil_bulat               int32
# teks                   object
# dtype: object

# %%
df.select_dtypes(include='number')
# Out:
#    bil_pecahan  bil_bulat
# 0          8.0         12
# 1         11.0          9
# 2         15.0          4
# 3         19.0          4
# 4         17.0         15

# %%
df.select_dtypes(include='float')
# Out:
#    bil_pecahan
# 0          8.0
# 1         11.0
# 2         15.0
# 3         19.0
# 4         17.0

# %%
df.select_dtypes(include='int')
# Out:
#    bil_bulat
# 0         12
# 1          9
# 2          4
# 3          4
# 4         15

# %%
df.select_dtypes(include='object')
# Out:
#   teks
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df.select_dtypes(include='datetime')
# Out:
#                 index
# 0 2023-01-01 00:00:00
# 1 2023-01-01 01:00:00
# 2 2023-01-01 02:00:00
# 3 2023-01-01 03:00:00
# 4 2023-01-01 04:00:00

# %%
df.select_dtypes(include=['number', 'object'])
# Out:
#    bil_pecahan  bil_bulat teks
# 0          8.0         12    A
# 1         11.0          9    B
# 2         15.0          4    C
# 3         19.0          4    D
# 4         17.0         15    E

# %%
#Pandas5

# %%
import pandas as pd
import numpy as np

n_rows = 5 
n_cols = 5 
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  7  5  5  6  1
# 1  8  6  7  7  3
# 2  7  6  6  2  6
# 3  4  3  1  8  2
# 4  1  6  9  1  2

# %%
df.loc[:, : :-1]
# Out:
#    E  D  C  B  A
# 0  1  6  5  5  7
# 1  3  7  7  6  8
# 2  6  2  6  6  7
# 3  2  8  1  3  4
# 4  2  1  9  6  1

# %%
df.loc[: :-1]
# Out:
#    A  B  C  D  E
# 4  1  6  9  1  2
# 3  4  3  1  8  2
# 2  7  6  6  2  6
# 1  8  6  7  7  3
# 0  7  5  5  6  1

# %%
df.loc[::-1, :]
# Out:
#    A  B  C  D  E
# 4  1  6  9  1  2
# 3  4  3  1  8  2
# 2  7  6  6  2  6
# 1  8  6  7  7  3
# 0  7  5  5  6  1

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  1  6  9  1  2
# 1  4  3  1  8  2
# 2  7  6  6  2  6
# 3  8  6  7  7  3
# 4  7  5  5  6  1

# %%
df.iloc[::-1, :]
# Out:
#    A  B  C  D  E
# 4  1  6  9  1  2
# 3  4  3  1  8  2
# 2  7  6  6  2  6
# 1  8  6  7  7  3
# 0  7  5  5  6  1

# %%
#Pandas6

n_rows = 5 
n_cols = 5 
cols = tuple('ABCDE')

df= pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  1  9  1  9  4
# 1  5  7  4  5  4
# 2  1  7  9  4  3
# 3  1  7  7  7  1
# 4  8  8  9  7  1

# %%
df.rename(columns={'C': 'Hobi'})
# Out:
#    A  B  Hobi  D  E
# 0  1  9     1  9  4
# 1  5  7     4  5  4
# 2  1  7     9  4  3
# 3  1  7     7  7  1
# 4  8  8     9  7  1

# %%
df.rename(columns={'C': 'LARI'})
# Out:
#    A  B  LARI  D  E
# 0  1  9     1  9  4
# 1  5  7     4  5  4
# 2  1  7     9  4  3
# 3  1  7     7  7  1
# 4  8  8     9  7  1

# %%
df.rename(columns={'A': 'Nama', 'B': 'Alamat', 'D': 'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     1       9  1     9  4
# 1     5       7  4     5  4
# 2     1       7  9     4  3
# 3     1       7  7     7  1
# 4     8       8  9     7  1

# %%
#Pandas7


import pandas as pd


df = pd._testing.makeMissingDataframe().reset_index()
df.head()

df = df.rename(columns={'index': 'Z'})
df.head()
# Out:
#             Z         A         B         C         D
# 0  SDe9zjdVkL  0.024731  0.490838  0.838699 -0.423538
# 1  eUcxp2WuuR       NaN       NaN       NaN       NaN
# 2  twQ1G5flZB       NaN       NaN       NaN       NaN
# 3  9ghuyyCkRQ -1.464146 -0.030611 -0.381684 -0.221199
# 4  mI6RqoEns7 -1.008979 -1.289062 -0.809639  0.442811

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#             Z
# 0  m2Mg2UwvHj
# 1  cDWYS7MLEM
# 2  nq6hPUzLbH
# 3  9fnFbDMWSL
# 4  qlw4Gq4qiL

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis=0)
df.head()
# Out:
#             Z         A         B         C         D
# 0  m2Mg2UwvHj -0.581853  3.218786  2.108909 -0.284251
# 2  nq6hPUzLbH  0.076813  0.204736  0.942355  1.818689
# 3  9fnFbDMWSL  1.563488 -0.207021 -0.625650 -0.871392
# 7  HhWHwi6ifn -0.630044 -0.986584  0.382925  0.693016
# 8  obCqJhWjPU -0.020913  0.159905  1.147345 -0.074097

# %%
df_backup = df.copy(deep=True)
df
# Out:
#              Z         A         B         C         D
# 0   SDe9zjdVkL  0.024731  0.490838  0.838699 -0.423538
# 1   eUcxp2WuuR       NaN       NaN       NaN       NaN
# 2   twQ1G5flZB       NaN       NaN       NaN       NaN
# 3   9ghuyyCkRQ -1.464146 -0.030611 -0.381684 -0.221199
# 4   mI6RqoEns7 -1.008979 -1.289062 -0.809639  0.442811
# 5   q6g5kdqeS6  1.582853  0.437580  0.453292 -0.832918
# 6   twjK6B9Mvm -2.200785  0.704280 -1.301482  0.473607
# 7   LzMnCgJ8Tl  1.275180  0.300919 -1.046604 -0.101590
# 8   dzK1Mf013n -0.754987  2.446914  0.327387 -0.167725
# 9   y0HHnJtPfM  0.584628  1.012055  2.157019 -0.638600
# 10  iF1jyxXKlp       NaN       NaN       NaN       NaN
# 11  GGOq1jZked  2.275051 -0.113372 -0.123271  0.336856
# 12  CfJXjitqXO       NaN       NaN       NaN       NaN
# 13  1FLxlnr85N       NaN       NaN       NaN       NaN
# 14  mmKqZvY4tI       NaN       NaN       NaN       NaN
# 15  QvRxUtLv6h       NaN       NaN       NaN       NaN
# ...

# %%
df = df_backup.copy(deep=True) 
df.isna().mean()
# Out:
# Z    0.000000
# A    0.366667
# B    0.366667
# C    0.366667
# D    0.366667
# dtype: float64

# %%
threshold = len(df) * 0.9
df = df.dropna(thresh=threshold, axis='columns')
df.head()
# Out:
#             Z
# 0  SDe9zjdVkL
# 1  eUcxp2WuuR
# 2  twQ1G5flZB
# 3  9ghuyyCkRQ
# 4  mI6RqoEns7

# %%
#Pandas8

data = {'A': [15, 15, 18, np.nan, 12], 
        'B':[15, 15, 18, np. nan, 12]}

df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %%
df ['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df ['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df ['A'] == df ['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df['A'].equals(df['B'])
# Out:
# True

# %%
df1 = df.copy(deep=True)

sama = df.equals(df1)
elementwise_comparison = df == df1

print("df dan df1 itu sama atau tidak?:", are_equal)
print("Perbandingan:\n", elementwise_comparison)
# Out:
# df dan df1 itu sama atau tidak?: True
# Perbandingan:
#         A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
